# %%
import pandas

# %% [markdown]
# ## Results of Eyehackers

# %%
results_eyehackers = pandas.read_csv('features_top.csv')

# %%
results_eyehackers
# Out:
#        polymorphism  differentiation
# 0    exm-rs12913832         0.516004
# 1         rs1129038         0.512454
# 2         rs2238289         0.418696
# 3     exm-rs1667394         0.366446
# 4      exm-rs916977         0.355542
# 5         rs8039195         0.300488
# 6         rs3935591         0.290173
# 7         rs7495174         0.244940
# 8         rs4778241         0.235946
# 9       rs201872292         0.226797
# 10        rs2240203         0.207363
# 11        rs8028689         0.206573
# 12       rs61756153         0.194469
# 13    exm-rs4778138         0.176802
# 14       rs11636232         0.166258
# 15        rs7183877         0.158472
# 16       rs61756152         0.155177
# 17        rs7174027         0.121005
# 18        rs4778232         0.120950
# 19        rs7179994         0.112729
# 20        rs1597196         0.098163
# 21        rs1470608         0.093686
# 22       rs11638265         0.092447
# 23        rs7170451         0.091681
# ...

# %%
polymorphism_eyehackers = results_eyehackers.polymorphism

# %%
polymorphism_eyehackers
# Out:
# 0      exm-rs12913832
# 1           rs1129038
# 2           rs2238289
# 3       exm-rs1667394
# 4        exm-rs916977
# 5           rs8039195
# 6           rs3935591
# 7           rs7495174
# 8           rs4778241
# 9         rs201872292
# 10          rs2240203
# 11          rs8028689
# 12         rs61756153
# 13      exm-rs4778138
# 14         rs11636232
# 15          rs7183877
# 16         rs61756152
# 17          rs7174027
# 18          rs4778232
# 19          rs7179994
# 20          rs1597196
# 21          rs1470608
# 22         rs11638265
# 23          rs7170451
# 24          rs1800411
# 25         rs12442147
# 26          rs1900758
# 27          rs7176632
# 28           rs921221
# 29          rs7179419
#             ...
# 92         rs10775246
# 93          rs1490079
# 94          rs2339262
# 95          rs8040604
# 96          rs8023338
# 97          rs9920714
# 98         rs16950272
# 99         rs11853140
# 100         rs2439421
# 101         rs8036143
# ...

# %% [markdown]
# ## Results of Biobank

# %%
results_biobank = pandas.read_csv('Marta-ped_sorted_raw.assoc', sep = ',')

# %%
results_biobank
# Out:
#        CHR               SNP         BP A1      F_A       F_U A2    CHISQ  \
# 0       15         rs1129038   28356859  G  0.48360  0.045790  A  2587.00
# 1       15    exm-rs12913832   28365618  A  0.48470  0.044220  G  2627.00
# 2       15      exm-rs916977   28513364  A  0.32180  0.031450  G  1567.00
# 3       15     exm-rs1667394   28530182  G  0.33300  0.031880  A  1645.00
# 4       15         rs8039195   28516084  C  0.27070  0.027730  T  1267.00
# 5       15         rs3935591   28374012  A  0.25630  0.023600  G  1214.00
# 6       15         rs2238289   28453215  C  0.23560  0.026240  T  1044.00
# 7       15         rs7495174   28344238  G  0.14120  0.011960  A   661.90
# 8       15         rs4778241   28338713  A  0.31110  0.108400  C   610.40
# 9       15         rs2240203   28494202  G  0.11580  0.006988  A   584.60
# 10      15         rs8028689   28488888  C  0.11540  0.006974  T   583.30
# 11      15         rs7183877   28365733  A  0.14380  0.019430  C   563.10
# ...

# %%
polymorphism_biobank = results_biobank[:121].SNP

# %%
polymorphism_biobank
# Out:
# 0           rs1129038
# 1      exm-rs12913832
# 2        exm-rs916977
# 3       exm-rs1667394
# 4           rs8039195
# 5           rs3935591
# 6           rs2238289
# 7           rs7495174
# 8           rs4778241
# 9           rs2240203
# 10          rs8028689
# 11          rs7183877
# 12         rs61756152
# 13         rs61756153
# 14        rs201872292
# 15         rs11636232
# 16      exm-rs4778138
# 17          rs7174027
# 18          rs7179994
# 19          rs4778232
# 20          rs1800407
# 21         exm1143095
# 22        rs118112076
# 23          rs1470608
# 24         rs11638265
# 25         rs12442147
# 26          rs1597196
# 27          rs1800411
# 28          rs7179419
# 29          rs7176632
#             ...
# 91          rs7176463
# 92         exm1170469
# 93         rs11858340
# 94         exm2252315
# 95          rs1603784
# 96          rs1528461
# 97         rs16950272
# 98         rs11853577
# 99          rs8042768
# 100          rs405103
# ...

# %%
results_together = polymorphism_eyehackers.append(polymorphism_biobank, ignore_index = False)

# %%
results_together
# Out:
# 0      exm-rs12913832
# 1           rs1129038
# 2           rs2238289
# 3       exm-rs1667394
# 4        exm-rs916977
# 5           rs8039195
# 6           rs3935591
# 7           rs7495174
# 8           rs4778241
# 9         rs201872292
# 10          rs2240203
# 11          rs8028689
# 12         rs61756153
# 13      exm-rs4778138
# 14         rs11636232
# 15          rs7183877
# 16         rs61756152
# 17          rs7174027
# 18          rs4778232
# 19          rs7179994
# 20          rs1597196
# 21          rs1470608
# 22         rs11638265
# 23          rs7170451
# 24          rs1800411
# 25         rs12442147
# 26          rs1900758
# 27          rs7176632
# 28           rs921221
# 29          rs7179419
#             ...
# 91          rs7176463
# 92         exm1170469
# 93         rs11858340
# 94         exm2252315
# 95          rs1603784
# 96          rs1528461
# 97         rs16950272
# 98         rs11853577
# 99          rs8042768
# 100          rs405103
# ...

# %% [markdown]
# # Test of features complete - 121 the most important polymorphisms are the same
